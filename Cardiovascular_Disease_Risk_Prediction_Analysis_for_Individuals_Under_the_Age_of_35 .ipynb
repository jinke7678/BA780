# %% [markdown]
# # **Cardiovascular Disease Risk Prediction Analysis for Individuals Under the Age of 35**

# %% [markdown]
# Team 6 members : **Mauro Wang, Yifan Bai, Jaishankar Govindaraj, Jinke Han, Shuo Ming Kuo, Srithijaa Sankepally**
#
# Date : **10/04/2023**

# %% [markdown]
# # Summary
#
# In recent years, there has been a concerning upward trend in the incidence of cardiovascular diseases (CVDs), especially among young generations in the U.S. In pursuit of better health for the youth, this project is designed to delve into a selected CVD dataset, employing various analytical methods to extract valuable insights. We will be utilizing data from the Centers for Disease Control and Prevention (CDC) Behavioral Risk Factor Surveillance System (BRFSS) for the year 2021.
#
# The primary objective of this project is to enhance awareness of CVDs and to encourage healthier lifestyle choices, particularly among individuals under the age of 35. Recently, the rise in CVD cases has made it a pivotal subject of research in the medical field. Our dataset, sourced from Kaggle, will be thoroughly explored through modeling and analysis, utilizing various methodologies.
#
# By conducting this analysis, we aspire to make a significant contribution to CVD awareness and encourage healthier living practices among the younger generation, including our classmates who are under the age of 35.

# %% [markdown]
# # Table of Contents
#
# 1. Introduction
#    - 1.1 Project Background and Purpose
#    - 1.2 Motivations
#    - 1.3 Methodology and Dataset
# 2. Data Pre-Processing
# 3. Data Analysis and Results
#    - 3.1 Does having depression affect the probability of getting heart disease if one has arthritis or diabetes already?
#    - 3.2 Does exercise influence the probability of getting heart disease in individuals who already have conditions like arthritis or other cancers?
#    - 3.3 Does exercise lower the risks of CVD in individuals with smoking history?
#    - 3.4 Does the self-assessment of individuals' health have any correlation with their likelihood of developing cardiovascular diseases?
#    - 3.5 Does the presence of Cardiovascular Disease result in any dietary restrictions for individuals?
# 4. Conclusions and Future Work
# 5. References
# 6. Appendices

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ##***1.1 Project background and purpose***
#
# Cardiovascular disease (CVD) refers to a group of conditions that affect the heart and blood vessels, including heart disease and strokes (From Google Scholar).  A steady rise in cardiovascular morbidity and mortality has been observed in young adults within the last decades.(https://www.sciencedirect.com/science/article/pii/S0021915023051936#cebib0010) It is crucial to examine the current status of CVD among young people in the United States because it provides valuable insights into the prevalence and impact of heart-related health issues in this demographic. And by analyzing this topic helps us assess the health and well-being of younger generations, identify potential risk factors, and develop strategies to promote heart health and prevent CVD in the future.
#
# The primal goal of this project is to raise awareness of CVD of young people and eventually improve their health. This goal would be achieved via multiple ways of efforts including analyzing diet habits and lifestyle that are relevant to CVD, discovering probabilities of having CVD among different demographic groups, building machine learning models to help predict the probability of having CVD in the future and what should be cautious about if already having CVD. In general all these efforts would be helpful to prevent having CVD and improve the general health status.

# %% [markdown]
# ##***1.2 Motivations***
#
# With the growing unhealthy lifestyle decisions among our generation, we got interested in evaluating how different lifestyle choices can directly affect Cardiovascular Diseases among our peers. Chapter 7 of the book “The Analytics Edge” played a significant role in sparking our interest in this important topic as well. “Prevention is better than cure” hence through this analysis we can see what factors can lead to CVDs and control those variables early on in order to stay clear of CVDs.

# %% [markdown]
# ##***1.3 Methodology and Dataset***
#
# The Dataset comprises **308854**  records with **19** variables,  including General_Health, Checkup, Exercise, Heart_Disease, Skin_Cancer, Other_Cancer, Depression, Diabetes, Arthritis, Sex, Age_Category, Height_(cm), Weight_(kg),BMI, Smoking_History, Alcohol_Consumption, Fruit_Consumption, Green_Vegetables_Comsumption, FriedPotato_Consumption. There are 7 numerical variables and 12 categorical variables.
#
# **Methodology:** In our dataset analysis, we took a comprehensive approach that blended descriptive, since we will be using measures like mean, median, mode, standard deviation, and graphs like scatter plots or bar charts, and inferential statistics, since we will be making inferences or drawing conclusions about a population based on a sample of data. Initially, we delved into data exploration, primarily utilizing summary statistics to grasp the distribution of variables. Following this, we employed data visualization techniques to uncover correlations and patterns within the dataset. To identify these patterns, we utilized a correlation matrix, highlighting which parameters exhibited the strongest correlation with CVD. However, it's essential to remember that correlation doesn't necessarily imply causation. This means that while our analysis revealed correlations, establishing causation would require further modeling and controlled studies. Additionally, it's worth noting that our dataset is heavily skewed toward individuals without CVD, with a ratio of nearly 99/1. This skewness presents challenges in determining the true validity of our findings.
#
#
# **Data Source:** For our analysis, we used data from the Centers for Disease Control and Prevention's Behavioral Risk Factor Surveillance System (BRFSS) for the year 2021. The BRFSS is well-known for providing reliable and comprehensive health-related data, making it a great choice for our research. You can access the original data source through this link:
#
# https://www.cdc.gov/brfss/annual_data/annual_2021.html
#
# The original dataset was quite extensive, with over 300 columns, and it was formatted for SAS using XPT and ASCII formats. However, we decided to work with a simpler version of the dataset, which was trimmed down to just 19 columns by a Kaggle user named Alphiree. We made this adjustment due to limitations in our ability to clean and process data that was not in CSV format. You can find the data we used at this link:
#
# https://www.kaggle.com/datasets/alphiree/cardiovascular-diseases-risk-prediction-dataset.

# %% [markdown]
# *   The dataset is sourced from the CDC and is part of the Behavioral Risk Factor Surveillance System for the year 2021.
# *   It comprises 308,854 rows and 19 columns, with each row corresponding to a data entry.
# *   The target value of interest is "Heart_Disease," which indicates whether a respondent has ever reported having heart disease.

# %% [markdown]
# Column | Description | Feature Type | Data Type
# -------|-------------|--------------|----------
# General_Health | How good do individuals consider their health | Categorical | string
# Check-up | Last visited a doctor for routine checkup | Categorical | string
# Exercise | Actively participating in any physical activity | Categorical | string
# Heart_Disease | Respondents that reported having Heart Disease | Categorical | string
# Skin_Cancer | Respondents that reported having skin cancer | Categorical | string
# Other_Cancer | Respondents that reported having any other types of cancer | Categorical | string
# Depression | Respondents that reported having a depressive disorder | Categorical | string
# Diabetes | Respondents that reported having diabetes | Categorical | string
# Arthritis | Respondents that reported having Arthritis | Categorical | string
# Sex | Respondent's Gender | Categorical | string
# Age_Category | Respondent’s Age | Categorical | string
# Height_(cm) | Respondent’s Height | Numerical | float64
# Weight_(kg) | Respondent’s Weight | Numerical | float64
# BMI | Respondent’s BMI | Numerical | float64
# Smoking_History | Respondent’s smoking history | Categorical | string
# Alcohol_Consumption | Respondent’s alcohol consumption | Numerical | float64
# Fruit_Consumption | Respondent’s fruit intake | Numerical | float64
# Green_Vegetables_Consumption | Respondent’s vegetable intake | Numerical | float64
# FriedPotato_Consumption | Respondent’s fried potato consumption | Numerical | float64

# %% [markdown]
# # 2. Data Pre-Processing

# %%
# We import necessary libraries for data analysis and visualization

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# We import the 'drive' module from the 'google.colab' library to Mount Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# We start out preprocessing with loading the dataset into our Colab environment. This is achieved using the Pandas library's read_csv() function. The dataset is stored as a CSV file, and we specify the file path to read it.

# %%
# We load the data from drive
CDC_data = pd.read_csv("/content/drive/MyDrive/BA780 Group 6 Project/CVD.csv")
CDC_data
# Out:
#        General_Health                  Checkup Exercise Heart_Disease  \
# 0                Poor  Within the past 2 years       No            No
# 1           Very Good     Within the past year       No           Yes
# 2           Very Good     Within the past year      Yes            No
# 3                Poor     Within the past year      Yes           Yes
# 4                Good     Within the past year       No            No
# ...               ...                      ...      ...           ...
# 308849      Very Good     Within the past year      Yes            No
# 308850           Fair  Within the past 5 years      Yes            No
# 308851      Very Good      5 or more years ago      Yes            No
# 308852      Very Good     Within the past year      Yes            No
# 308853      Excellent     Within the past year      Yes            No
#
#        Skin_Cancer Other_Cancer Depression  \
# 0               No           No         No
# ...

# %% [markdown]
# ## ***2.1 Filtering the data for relevant age group***

# %% [markdown]
# To start our data pre-processing, we focus on the 'age_category' column. Our goal is to pick out specific age groups that matter for our analysis: 18-24, 25-29, and 30-34. We do this by filtering the dataset to keep only the rows with 'age_category' in one of these three ranges.

# %%
# We filter rows by "Age_Category" (values: "18-24", "25-29", "30-34"), sort by "Age_Category," and reset the index.

CDC_data = CDC_data.loc[CDC_data["Age_Category"].isin(["18-24", "25-29", "30-34"])].sort_values("Age_Category").reset_index(drop=True)

# %%
# We Check whether the filter and sort are corretly applied

CDC_data.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0      Very Good  Within the past 2 years      Yes            No          No
# 1           Good     Within the past year       No            No          No
# 2      Very Good      5 or more years ago      Yes            No          No
# 3      Very Good     Within the past year      Yes            No          No
# 4      Excellent     Within the past year      Yes            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No        Yes       No        No  Female        18-24
# 1           No         No       No        No  Female        18-24
# 2           No         No       No        No    Male        18-24
# 3           No         No       No        No    Male        18-24
# 4           No         No       No        No    Male        18-24
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %% [markdown]
# ##***2.2 Checking for Missing Values***

# %% [markdown]
# We perform a thorough check of the data to identify any missing values. If we do discover any, our next step will involve data cleaning to handle and correct these missing values, since they might contains insightful information regarding our data. Fortunately, our data inspection reveals that there are no missing values present. Hence,there is no need for us to perform imputation or fill in any missing data points.

# %%
# We check and sum each column's missing value
CDC_data.isna().sum()
# Out:
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Other_Cancer                    0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %% [markdown]
# ##***2.3 Data Exploration***

# %% [markdown]
# We examine the data and observe that it contains two primary data types: float64 and object. However, it's worth noting that some of the float objects have a binary nature, meaning they represent either 'yes' or 'no.' We plan to address this binary data issue during the data cleaning phase of our analysis.

# %%
# We check every column's datatype
CDC_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52603 entries, 0 to 52602
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   General_Health                52603 non-null  object
#  1   Checkup                       52603 non-null  object
#  2   Exercise                      52603 non-null  object
#  3   Heart_Disease                 52603 non-null  object
#  4   Skin_Cancer                   52603 non-null  object
#  5   Other_Cancer                  52603 non-null  object
#  6   Depression                    52603 non-null  object
#  7   Diabetes                      52603 non-null  object
#  8   Arthritis                     52603 non-null  object
#  9   Sex                           52603 non-null  object
#  10  Age_Category                  52603 non-null  object
#  11  Height_(cm)                   52603 non-null  float64
# ...

# %% [markdown]
# We compute the count of unique values for each column as part of our data quality assessment. This step helps us understand the diversity and distribution of values within each column, which is crucial for assessing the overall data quality.

# %%
# We calculate each column's unique value count
CDC_data.nunique()
# Out:
# General_Health                     5
# Checkup                            5
# Exercise                           2
# Heart_Disease                      2
# Skin_Cancer                        2
# Other_Cancer                       2
# Depression                         2
# Diabetes                           4
# Arthritis                          2
# Sex                                2
# Age_Category                       3
# Height_(cm)                       77
# Weight_(kg)                      408
# BMI                             2474
# Smoking_History                    2
# Alcohol_Consumption               31
# Fruit_Consumption                 57
# Green_Vegetables_Consumption      54
# FriedPotato_Consumption           57
# dtype: int64

# %% [markdown]
# We create a summary table to better understand the numerical data. It gives us important statistics and patterns that help us see what's going on in the dataset.

# %%
# We show summary statistic for each column to discover outliers in the distribution

CDC_data.describe()
# Out:
#         Height_(cm)   Weight_(kg)           BMI  Alcohol_Consumption  \
# count  52603.000000  52603.000000  52603.000000         52603.000000
# mean     172.139593     81.582937     27.465423             4.724445
# std       10.776357     22.081939      6.781640             6.800725
# min       94.000000     31.750000     12.160000             0.000000
# 25%      165.000000     65.770000     22.800000             0.000000
# 50%      173.000000     77.110000     25.840000             2.000000
# 75%      180.000000     92.080000     30.680000             7.000000
# max      229.000000    293.020000     96.520000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count       52603.000000                  52603.000000
# mean           27.531186                     13.272399
# std            24.303057                     15.284404
# min             0.000000                      0.000000
# 25%            10.000000                      4.000000
# ...

# %% [markdown]
# The measurement units for Alcohol Consumption, Fruit Consumption, Green Vegetables Consumption, and Fried Potato Consumption are expressed in terms of monthly frequency. In this context, a value of 128 signifies that an individual consumes the respective item that many times within the specified time frame. Given this information we calculate the percentages for certain relevant statistics for this data.

# %%
#We calculate the percentage of individuals with zero alcohol consumption per month

CDC_data[CDC_data["Alcohol_Consumption"] == 0].shape[0] / CDC_data.shape[0]*100
# Out:
# 37.55299127426193

# %%
#We calculate the percentage of individuals with more than 15 alcohol consumptions per month

CDC_data[CDC_data["Alcohol_Consumption"] > 15].shape[0] / CDC_data.shape[0]*100
# Out:
# 8.03376233294679

# %%
#We calculate the percentage of individuals with zero fried potato consumption per month

CDC_data[CDC_data["FriedPotato_Consumption"] == 0].shape[0] / CDC_data.shape[0]*100
# Out:
# 6.34184362108625

# %%
#We calculate the percentage of individuals with 30 fried potato consumptions per month

CDC_data[CDC_data["FriedPotato_Consumption"] > 30].shape[0] / CDC_data.shape[0]*100
# Out:
# 1.1292131627473718

# %%
#We calculate the percentage of individuals that are underweight

CDC_data[CDC_data["BMI"] < 18.5].shape[0] / CDC_data.shape[0]*100
# Out:
# 2.684257551850655

# %%
#We calculate the percentage of individuals that are overweight

CDC_data[CDC_data["BMI"] > 25].shape[0] / CDC_data.shape[0]*100
# Out:
# 57.806588977814954

# %%
#We calculate the percentage of individuals that are obese

CDC_data[CDC_data["BMI"] > 30].shape[0] / CDC_data.shape[0]*100
# Out:
# 27.582077067847845

# %% [markdown]
# We create a summary table to better understand the categorical data. It gives us important information on the value counts, the mode and its frequency on the dataset

# %%
# We generate summary statistics for categorical columns in the data

CDC_data.describe(include=object)
# Out:
#        General_Health               Checkup Exercise Heart_Disease  \
# count           52603                 52603    52603         52603
# unique              5                     5        2             2
# top         Very Good  Within the past year      Yes            No
# freq            20191                 32251    44497         52195
#
#        Skin_Cancer Other_Cancer Depression Diabetes Arthritis    Sex  \
# count        52603        52603      52603    52603     52603  52603
# unique           2            2          2        4         2      2
# top             No           No         No       No        No   Male
# freq         52331        51963      39175    50694     49468  28307
#
#        Age_Category Smoking_History
# count         52603           52603
# unique            3               2
# top           18-24              No
# freq          18681           39028

# %%
# We print unique values for each categorical column in the data

categorical_columns = CDC_data.select_dtypes(include=['object'])
for i in categorical_columns:
  print("{0:15s} shape={1}".format(i, CDC_data[i].unique()))
# Out:
# General_Health  shape=['Very Good' 'Good' 'Excellent' 'Fair' 'Poor']
# Checkup         shape=['Within the past 2 years' 'Within the past year' '5 or more years ago'
#  'Within the past 5 years' 'Never']
# Exercise        shape=['Yes' 'No']
# Heart_Disease   shape=['No' 'Yes']
# Skin_Cancer     shape=['No' 'Yes']
# Other_Cancer    shape=['No' 'Yes']
# Depression      shape=['Yes' 'No']
# Diabetes        shape=['No' 'Yes, but female told only during pregnancy' 'Yes'
#  'No, pre-diabetes or borderline diabetes']
# Arthritis       shape=['No' 'Yes']
# Sex             shape=['Female' 'Male']
# Age_Category    shape=['18-24' '25-29' '30-34']
# Smoking_History shape=['No' 'Yes']

# %%
# We check the first few rows of the data

CDC_data.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0      Very Good  Within the past 2 years      Yes            No          No
# 1           Good     Within the past year       No            No          No
# 2      Very Good      5 or more years ago      Yes            No          No
# 3      Very Good     Within the past year      Yes            No          No
# 4      Excellent     Within the past year      Yes            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No        Yes       No        No  Female        18-24
# 1           No         No       No        No  Female        18-24
# 2           No         No       No        No    Male        18-24
# 3           No         No       No        No    Male        18-24
# 4           No         No       No        No    Male        18-24
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %% [markdown]
# We investigate the categorical variables and their distribution to determine if there is any skewness present. This helps us identify if certain categories are significantly more common than others, which can impact our analysis.

# %%
# We print the value counts for each categorical column in the data

for column in categorical_columns:
    print(f"Value counts for {column}:")
    print(CDC_data[column].value_counts())
    print("\n")
# Out:
# Value counts for General_Health:
# Very Good    20191
# Good         14713
# Excellent    13363
# Fair          3698
# Poor           638
# Name: General_Health, dtype: int64
#
#
# Value counts for Checkup:
# Within the past year       32251
# Within the past 2 years     9663
# Within the past 5 years     5988
# 5 or more years ago         4246
# Never                        455
# Name: Checkup, dtype: int64
#
#
# Value counts for Exercise:
# Yes    44497
# No      8106
# Name: Exercise, dtype: int64
#
#
# Value counts for Heart_Disease:
# No     52195
# Yes      408
# Name: Heart_Disease, dtype: int64
#
#
# Value counts for Skin_Cancer:
# No     52331
# Yes      272
# Name: Skin_Cancer, dtype: int64
#
#
# Value counts for Other_Cancer:
# No     51963
# Yes      640
# Name: Other_Cancer, dtype: int64
#
#
# Value counts for Depression:
# No     39175
# Yes    13428
# Name: Depression, dtype: int64
#
#
# Value counts for Diabetes:
# No                                            50694
# ...

# %% [markdown]
# ## ***2.4 Data Cleaning***

# %% [markdown]
# To start our data cleaning process, we begin by checking for duplicate entries in the dataset, since they are redundant and do not contribute to our analysis. We will identify and remove one of the duplicate records to ensure data integrity.

# %%
# We find and display the duplicate rows in the data

CDC_data[CDC_data.duplicated(keep = False)].sort_values(["Weight_(kg)", "General_Health"])
# Out:
#       General_Health                  Checkup Exercise Heart_Disease  \
# 4362       Excellent     Within the past year      Yes            No
# 14737      Excellent     Within the past year      Yes            No
# 4960       Very Good     Within the past year      Yes            No
# 17191      Very Good     Within the past year      Yes            No
# 2123       Very Good     Within the past year      Yes            No
# 5566       Very Good     Within the past year      Yes            No
# 10054      Very Good     Within the past year      Yes            No
# 15356      Very Good     Within the past year      Yes            No
# 784        Excellent     Within the past year      Yes            No
# 12277      Excellent     Within the past year      Yes            No
# 1401       Very Good     Within the past year      Yes            No
# 13431      Very Good     Within the past year      Yes            No
# 15490      Very Good     Within the past year      Yes            No
# ...

# %%
# We calculate and print the number of duplicate rows in the data

duplicates_number = CDC_data.duplicated().sum()

print("Number of duplicates:", duplicates_number)
# Out:
# Number of duplicates: 16

# %%
# We remove the duplicate rows in the data

CDC_data.drop_duplicates(inplace = True)
CDC_data
# Out:
#       General_Health                  Checkup Exercise Heart_Disease  \
# 0          Very Good  Within the past 2 years      Yes            No
# 1               Good     Within the past year       No            No
# 2          Very Good      5 or more years ago      Yes            No
# 3          Very Good     Within the past year      Yes            No
# 4          Excellent     Within the past year      Yes            No
# ...              ...                      ...      ...           ...
# 52598      Excellent     Within the past year      Yes            No
# 52599      Very Good     Within the past year      Yes            No
# 52600      Very Good     Within the past year      Yes            No
# 52601      Excellent     Within the past year      Yes            No
# 52602      Very Good      5 or more years ago      Yes            No
#
#       Skin_Cancer Other_Cancer Depression  \
# 0              No           No        Yes
# 1              No           No         No
# ...

# %% [markdown]
# While conducting our data analysis, we observed that the "Diabetes" column contains four unique values. To simplify our analysis and make it more straightforward, we will simplify these values by categorizing them as 'No' and 'Yes'.

# %%
# Transforming the "Diabetes" column

CDC_data["Diabetes"] = CDC_data["Diabetes"].str[:3].str.replace(',', '')
for i in categorical_columns:
  print("{0:15s} shape={1}".format(i, CDC_data[i].unique()))
# Out:
# General_Health  shape=['Very Good' 'Good' 'Excellent' 'Fair' 'Poor']
# Checkup         shape=['Within the past 2 years' 'Within the past year' '5 or more years ago'
#  'Within the past 5 years' 'Never']
# Exercise        shape=['Yes' 'No']
# Heart_Disease   shape=['No' 'Yes']
# Skin_Cancer     shape=['No' 'Yes']
# Other_Cancer    shape=['No' 'Yes']
# Depression      shape=['Yes' 'No']
# Diabetes        shape=['No' 'Yes']
# Arthritis       shape=['No' 'Yes']
# Sex             shape=['Female' 'Male']
# Age_Category    shape=['18-24' '25-29' '30-34']
# Smoking_History shape=['No' 'Yes']

# %% [markdown]
# With all columns now containing only 'yes' and 'no' values, we can perform binary encoding, assigning 'yes' as 1 and 'no' as 0. This binary encoding simplifies our data and facilitates easier plotting and analysis.

# %%
# We identify the binary columns in the data, excluding 'Diabetes'

binary_columns = CDC_data.columns[CDC_data.isin(['Yes', 'No']).any()].tolist()
binary_columns
# Out:
# ['Exercise',
#  'Heart_Disease',
#  'Skin_Cancer',
#  'Other_Cancer',
#  'Depression',
#  'Diabetes',
#  'Arthritis',
#  'Smoking_History']

# %%
# We binary encode the binary columns of our data

for i in binary_columns:
  CDC_data[i] = CDC_data[i].map(dict(Yes=1, No=0))
CDC_data.head()
# Out:
#   General_Health                  Checkup  Exercise  Heart_Disease  \
# 0      Very Good  Within the past 2 years         1              0
# 1           Good     Within the past year         0              0
# 2      Very Good      5 or more years ago         1              0
# 3      Very Good     Within the past year         1              0
# 4      Excellent     Within the past year         1              0
#
#    Skin_Cancer  Other_Cancer  Depression  Diabetes  Arthritis     Sex  \
# 0            0             0           1         0          0  Female
# 1            0             0           0         0          0  Female
# 2            0             0           0         0          0    Male
# 3            0             0           0         0          0    Male
# 4            0             0           0         0          0    Male
#
#   Age_Category  Height_(cm)  Weight_(kg)    BMI  Smoking_History  \
# 0        18-24        157.0        55.79  22.50                0
# ...

# %% [markdown]
# For the column "General_Health," we can employ ordinal encoding, which involves assigning ordinal values based on a scale. In this case, we can use the following scale: {'Poor': 0, 'Fair': 1, 'Good': 2, 'Very Good': 3, 'Excellent': 4}. This encoding allows us to represent the varying levels of general health numerically.

# %%
# We perform ordinal encoding for the "General_Health" column, mapping categorical values to numerical values

CDC_data["General_Health"] = CDC_data["General_Health"].map(dict({'Poor': 0, 'Fair': 1, 'Good': 2, 'Very Good': 3, 'Excellent': 4}))
CDC_data.head()
# Out:
#    General_Health                  Checkup  Exercise  Heart_Disease  \
# 0               3  Within the past 2 years         1              0
# 1               2     Within the past year         0              0
# 2               3      5 or more years ago         1              0
# 3               3     Within the past year         1              0
# 4               4     Within the past year         1              0
#
#    Skin_Cancer  Other_Cancer  Depression  Diabetes  Arthritis     Sex  \
# 0            0             0           1         0          0  Female
# 1            0             0           0         0          0  Female
# 2            0             0           0         0          0    Male
# 3            0             0           0         0          0    Male
# 4            0             0           0         0          0    Male
#
#   Age_Category  Height_(cm)  Weight_(kg)    BMI  Smoking_History  \
# 0        18-24        157.0        55.79  22.50                0
# ...

# %% [markdown]
# We've observed an unusually high BMI value of 96.52, which appears to be an outlier. To verify the consistency of this column, we can cross-reference it with the BMI calculation formula. The BMI formula is typically calculated as follows:
#
# $BMI = \frac{{\text{weight in kilograms}}}{{(\text{height in meters})^2}}$
#
# By using this formula and comparing it to the values in the column, we can ensure data consistency and identify any potential errors.

# %%
# We calculate "Predicted_bmi" from our data based on weight and height

CDC_data["Predicted_bmi"] = CDC_data["Weight_(kg)"] /((CDC_data["Height_(cm)"]/100)**2)
CDC_data.describe()
# Out:
#        General_Health      Exercise  Heart_Disease   Skin_Cancer  \
# count    52587.000000  52587.000000   52587.000000  52587.000000
# mean         2.797231      0.845855       0.007759      0.005172
# std          0.939736      0.361091       0.087741      0.071734
# min          0.000000      0.000000       0.000000      0.000000
# 25%          2.000000      1.000000       0.000000      0.000000
# 50%          3.000000      1.000000       0.000000      0.000000
# 75%          4.000000      1.000000       0.000000      0.000000
# max          4.000000      1.000000       1.000000      1.000000
#
#        Other_Cancer    Depression      Diabetes     Arthritis   Height_(cm)  \
# count  52587.000000  52587.000000  52587.000000  52587.000000  52587.000000
# mean       0.012170      0.255329      0.027307      0.059615    172.139825
# std        0.109647      0.436050      0.162978      0.236775     10.777145
# ...

# %%
# Check the outlier data of BMI (BMI=96.52)
CDC_data.loc[CDC_data["BMI"] == 96.520000]
# Out:
#       General_Health              Checkup  Exercise  Heart_Disease  \
# 7824               4  5 or more years ago         1              0
#
#       Skin_Cancer  Other_Cancer  Depression  Diabetes  Arthritis   Sex  \
# 7824            0             0           0         0          0  Male
#
#      Age_Category  Height_(cm)  Weight_(kg)    BMI  Smoking_History  \
# 7824        18-24        165.0       263.08  96.52                1
#
#       Alcohol_Consumption  Fruit_Consumption  Green_Vegetables_Consumption  \
# 7824                  0.0               30.0                          30.0
#
#       FriedPotato_Consumption  Predicted_bmi
# 7824                     30.0      96.631772

# %%
# We locate the rows where the difference between "BMI" and "Predicted_bmi" is greater than 0.5

CDC_data.loc[(CDC_data["BMI"] - CDC_data["Predicted_bmi"]) > 0.5]
# Out:
#        General_Health                  Checkup  Exercise  Heart_Disease  \
# 11432               0  Within the past 5 years         0              0
#
#        Skin_Cancer  Other_Cancer  Depression  Diabetes  Arthritis     Sex  \
# 11432            0             0           1         0          1  Female
#
#       Age_Category  Height_(cm)  Weight_(kg)    BMI  Smoking_History  \
# 11432        18-24         97.0        88.45  94.94                0
#
#        Alcohol_Consumption  Fruit_Consumption  Green_Vegetables_Consumption  \
# 11432                  0.0               60.0                          30.0
#
#        FriedPotato_Consumption  Predicted_bmi
# 11432                      8.0      94.005739

# %% [markdown]
# We've observed that only one entry deviates from our expected value by slightly more than 0.5, but it's not significantly different. Therefore, we'll retain this entry and won't drop any values from the dataset.

# %% [markdown]
# ## ***2.5 Further Data Analysis***

# %% [markdown]
# We use the groupby function to perform data grouping, enabling us to find insightful information within the dataset. This approach allows us to explore trends, patterns, and interesting details that may not be visible when examining the data as a whole.

# %%
# We group data by Alcohol_Consumption and calculate mean for Heart_Disease

grouped_data_for_AC = CDC_data.groupby('Alcohol_Consumption')['Heart_Disease'].mean().reset_index()
grouped_data_for_AC.Heart_Disease = grouped_data_for_AC.Heart_Disease * 100
grouped_data_for_AC
# Out:
#     Alcohol_Consumption  Heart_Disease
# 0                   0.0       0.835909
# 1                   1.0       0.666667
# 2                   2.0       0.958543
# 3                   3.0       0.495994
# 4                   4.0       0.747664
# 5                   5.0       0.325600
# 6                   6.0       0.481928
# 7                   7.0       0.362757
# 8                   8.0       0.687049
# 9                   9.0       0.000000
# 10                 10.0       0.606673
# 11                 11.0      10.526316
# 12                 12.0       0.616592
# 13                 13.0       3.571429
# 14                 14.0       0.735294
# 15                 15.0       0.902935
# 16                 16.0       1.093750
# 17                 17.0       0.000000
# 18                 18.0       1.639344
# 19                 19.0       0.000000
# 20                 20.0       0.558659
# 21                 21.0       0.000000
# 22                 22.0       3.333333
# ...

# %% [markdown]
# After an in depth analysis, we did not observe any significant patterns or correlations between alcohol consumption and the risk of cardiovascular disease (CVD) within our dataset. This suggests that alcohol consumption may not be a prominent factor in influencing CVD risk based on the data we have examined.

# %%
# We group data by Green_Vegetables_Consumption and calculate mean for Heart_Disease

grouped_data_for_GV = CDC_data.groupby('Green_Vegetables_Consumption')['Heart_Disease'].mean().reset_index()
grouped_data_for_GV.Heart_Disease = grouped_data_for_GV.Heart_Disease * 100
grouped_data_for_GV
# Out:
#     Green_Vegetables_Consumption  Heart_Disease
# 0                            0.0       0.965147
# 1                            1.0       0.820068
# 2                            2.0       0.588928
# 3                            3.0       1.222826
# 4                            4.0       0.466969
# 5                            5.0       0.719942
# 6                            6.0       0.630915
# 7                            7.0       0.819672
# 8                            8.0       0.684433
# 9                            9.0       0.000000
# 10                          10.0       0.943396
# 11                          11.0       0.000000
# 12                          12.0       0.678769
# 13                          13.0       0.000000
# 14                          14.0       0.000000
# 15                          15.0       0.843486
# 16                          16.0       0.645161
# 17                          17.0       0.000000
# 18                          18.0       5.555556
# ...

# %% [markdown]
# The same can be seen from the green vegetables consumption

# %%
# We group data by Sex and calculate mean for Heart_Disease

grouped_data_for_Sex = CDC_data.groupby('Sex')['Heart_Disease'].mean().reset_index()
grouped_data_for_Sex.Heart_Disease = grouped_data_for_Sex.Heart_Disease * 100
grouped_data_for_Sex
# Out:
#       Sex  Heart_Disease
# 0  Female       0.691671
# 1    Male       0.848116

# %% [markdown]
# In our analysis, we have identified a notable pattern indicating that males are more likely to develop cardiovascular diseases (CVDs) compared to females. This conclusion is drawn from the observation that while the gender distribution in the dataset is nearly equal between males and females, the probability of CVD occurrence is higher among males. This finding suggests a gender-based disparity in CVD risk within the dataset.

# %%
# We group data by Exercise and calculate mean for Heart_Disease

grouped_data_for_Ex = CDC_data.groupby('Exercise')['Heart_Disease'].mean().reset_index()
grouped_data_for_Ex.Heart_Disease = grouped_data_for_Ex.Heart_Disease * 100
grouped_data_for_Ex
# Out:
#    Exercise  Heart_Disease
# 0         0       1.159635
# 1         1       0.705919

# %% [markdown]
# Our analysis shows that people who exercise are less likely to have cardiovascular diseases (CVDs).

# %% [markdown]
# # 3. Data Analysis and Results

# %% [markdown]
# ##***3.1 Does having depression affect the probability of getting heart disease if one has arthritis or diabetes already?***

# %% [markdown]
# From the given data, we would like to find out whether having depression increases one's probability of getting heart disease given the chance that the person is diagnosed with arthritis or diabetes.

# %% [markdown]
# To answer this question, we will be using the following variables: Arthritis, Depression, Diabetes, and Sex. The specific reasons for selecting these variables are as follows: both arthritis and diabetes increase one's probability of getting heart disease, as arthritis implies inflammation within the human body, weakening blood vessels; diabetes indicates high blood sugar within the blood vessels, also weakening them. Additionally, we considered that having arthritis or diabetes can affect one's mindset and therefore increase the chance of having depression. We also chose to plot for sex since we found significant differences in probability between the two genders. Lastly, since we were curious about whether depression weakens one's body, making it more vulnerable to heart disease, we will plot it on our x-axis.

# %%
sns.catplot(kind = "bar", x = "Depression", y = "Heart_Disease", data = CDC_data, hue = "Sex", col = "Arthritis", row = "Diabetes", palette = "pastel");
plt.suptitle("Probability of having a Heart Disease by Depression, Diabetes, Sex and Arthritis", y=1.05)
plt.show();

# %% [markdown]
# From the graph above, we can tell that there's no significant difference between having depression or not when the person has diabetes only or doesn't have any. On the other hand, the probability slightly increases if one has arthritis and depression at the same time. However, the bottom-right plot shows us an interesting fact that both the probability increases despite having depression or not, indicating that diabetes and arthritis do affect the likelihood of getting heart disease. What's even more fascinating is that people tend to be two times more likely to have heart disease if they have depression compared to those who don't.
#
# Thus, our conclusion is that depression does influence the probability of having heart disease, though it's not obvious when one doesn't have other diseases but is especially significant when you have both arthritis and diabetes.

# %% [markdown]
# ##***3.2 Does exercise influence the probability of getting heart disease in individuals who already have conditions like arthritis or other cancers?***

# %% [markdown]
# In the first question, we observed that depression, diabetes, and arthritis indeed have an impact on the probability of having heart disease. Consequently, we aim to conduct further research on how to reduce the risk of heart disease in individuals who may be dealing with less favorable health conditions(such as having cancer or arthritis).
#
# To explore this question, we will use the following variables: Other_cancer, Arthritis, Exercise, and Sex. Upon calculating a heatmap of the correlation matrix for the numeric columns of the dataset, we have identified that the variables "Other_cancer" and "Arthritis" exhibit relatively higher correlation values with heart disease, namely 0.06 and 0.07, respectively. Therefore, we have chosen these two representative disease variables, "Other_cancer" and "Arthritis," for further analysis.
#
# We want to know if engaging in doing exercise can lead to improved cardiovascular health(CVH), even when you have other medical conditions(like other cancer and arthritis). Does exercise reduce the risk of heart disease? The chart below illustrates our findings.

# %%
sns.catplot(kind = "bar", x = "Exercise", y = "Heart_Disease", data = CDC_data, hue = "Sex", col = "Arthritis", row = "Other_Cancer", palette = "pastel");
plt.suptitle("Probability of having a Heart Disease by Exercise, Other Cancer, Sex and Arthritis", y=1.05)
plt.show();

# %% [markdown]
# From the chart above, we can see that when a person does not have other cancer or arthritis, there is no significant difference in having the risk of heart disease, whether they engage in exercise or not. Moreover, when an individual has either other cancer or arthritis as their single disease condition, their risk of heart disease is slightly higher compared to those without other cancer and arthritis. Exercise does not have a significant impact on the probability of developing heart disease in this scenario; it only provides a modest reduction in the risk of having heart disease.
#
# However, a noteworthy discovery emerges when individuals have both cancer and arthritis(the subplot in the lower right corner). In such cases, exercise plays a vital role in significantly lowering the risk of heart disease, particularly among males, where it more than halves the probability.
#
# In conclusion, exercise appears to be particularly beneficial for individuals dealing with multiple health conditions, effectively reducing the risk of heart disease, especially in cases of concurrent cancer and arthritis for males.

# %% [markdown]
# ##***3.3 Does exercise lower the risks of CVD in individuals with smoking history?***
#
# Drinking and smoking are widely considered bad for general health, including heart conditions, and are habits difficult to get rid of. On the other hand, exercising has a much better reputation.
#
# In this part we are trying to explore whether exercising mitigate the risks of CVD in individuals who consume alcohol and smoke, in pursuit of some practical advices for these group of people to prevent them from serious heart disearses and improve their health conditions.
#
# ***Variables:***
#
# To answer this question, the following variables need to be taken into consideration: Exercise is a variable that signifies the current participation of respondents in physical activities within the last month, this is relevant, since we want to find the effect of it on smoking. Smoking_History indicates whether participants have a history of smoking. Additionally, Heart_Diseases identifies whether respondents have reported having coronary heart disease or myocardial infarction. We will also take gender in consideration, since we believe that it might be relevant in answering this question. These variables are integral to our analysis of health-related factors.
#
# ***Chart:***
#
# Below is the bar chart that shows the risks of CVD in individuals with/without a smoking history and have/have not exercised last month (separated by Sex).

# %%
sns.catplot(kind = "bar", x = "Exercise" , y = "Heart_Disease", data = CDC_data, col = "Smoking_History", hue = "Sex", palette = "pastel");
plt.suptitle("Probability of having a Heart Disease by Exercise, Sex and Smoking History", y=1.05)
plt.show();

# %% [markdown]
# ***Discoveries:***
#
# **Firstly, individuals who have a smoking history in general have higher risks of CVD regardless of sex and exercise habits.** This finding corresponds with past research results and common sense.
#
# **Secondly, individuals who has a exercise habit is less likely to have CVD regardless of sex and smoking history.** This is an strong evidence that exercising can help to mitigate the risks of CVD in individuals who smoke, and, of course, in those who do not smoke as weell.
#
# **Thirdly, smoking increase more risks of CVD in male than in female.** Among individuals who do not have a smoking history, male and female respondants share similar risks of CVD. However, male respondants among smoking group are noticebly riskier than female respondants of CVD, regardless of having a exercise habit or not.
#
# ***Conclusion:***
#
# In conclusion, exercising does help lower the risks of CVD in individuals with smoking history. We thus encourage people to develop a exercise habit to help prevent CVD, especially people who smoke. However, we do recommend people to quit smoking first since non-smokers have a much lower risks in CVD.

# %% [markdown]
# ##***3.4 Does the self-assessment of individuals' health have any correlation with their likelihood of developing cardiovascular diseases?***

# %% [markdown]
# This research question is intriguing because it explores how people's own perceptions of their health might relate to their chances of getting heart diseases. We're not only looking at how people who feel healthy are doing, but also at the opposite situation. We want to know if people with Cardiovascular Disease tend to say they feel less healthy. Finding a possible link between how people rate their own health and their risk of heart diseases could have a big impact on public health and healthcare strategies. If we find a strong connection, it could highlight the importance of considering what people think about their own health when we're trying to prevent heart diseases. It might also give us clues about how our thoughts and behaviors affect our health.

# %% [markdown]
# We will focus our analysis on two key variables. First, we have "General_Health," which answers the question: "Would you say that in general your health is...?" This variable will be used to assesses respondents' overall health perceptions. The second variable, denoted as "Heart_Disease," identifies respondents who have reported coronary heart disease or myocardial infarction. We'll be categorizing the data based on age because we suspect that different age groups may have varying levels of self-awareness about their health.

# %%
sns.catplot(kind = "bar", y = "Heart_Disease" , x = "General_Health", data = CDC_data, hue = "Age_Category", palette = "pastel");
plt.ylabel("Probability of Heart Disease")
plt.suptitle("Probability of having a Heart Disease by General Health and Sex", y=1.05)
plt.show();

# %% [markdown]
# The graph clearly illustrates a strong correlation between general health and the risk of cardiovascular disease. Notably, as general health evaluations decrease, the risk of developing cardiovascular disease increases. An interesting observation from the graph is that individuals in the younger age brackets are less likely to develop cardiovascular diseases compared to their peers of the same age with similar general health scores. One possible explanation for this phenomenon could be that older individuals have a better understanding of their health, leading them to report any health issues more accurately. As a result, their reported rates of cardiovascular disease are higher compared to younger individuals who might be underestimating their health issues. Alternatively, it's possible that younger people have more robust immune systems compared to their older counterparts, which could explain their lower likelihood of developing cardiovascular diseases. This could be because their hearts are generally stronger and healthier due to their youth. In summary, the graph suggests a clear link between self-reported general health and cardiovascular disease risk. The age-related differences in reporting and potential variations in immune system strength among age groups offer intriguing insights into the observed patterns that we can further research.

# %% [markdown]
# ##***3.5 Does the presence of Cardiovascular Disease result in any dietary restrictions for individuals?***

# %% [markdown]
# From the given data, we are trying to understand if having Cardiovascular Disease changes people's diet and if there are any specific types of food they try to avoid or eat more.

# %% [markdown]
# To answer this question, we will be using the following variables:
# 1. Green Vegetable consumption
# 2. Fried Potato consumption
#
# The reason we specifically chose these variables is because here we are comparing two types of food, healthy and unhealthy. Comparing two such food groups will help us understand the choices people with Cardiovascular Disease make and if they restrict themselves from any of these.
#
# Green Vegetables are known to be very nutritious and have lots of health benefits if consumed the right way. They are recommended to everyone who wants a healthy lifestyle, regardless of their underlying health conditions. Whereas Fried Potatoes have high levels of sodium as well as saturated and trans fats. These often led to high cholesterol and hence, people of all age groups are encouraged to avoid such foods.

# %%
sns.relplot(kind = "scatter", x = "Green_Vegetables_Consumption", y = "FriedPotato_Consumption" , data = CDC_data, hue = "Heart_Disease", alpha = 0.9,palette = "pastel");
plt.xlabel("Green Vegetables Consumption per Month")
plt.ylabel("Fried Potato Consumption per Month")
plt.suptitle("Scatter plot of Green Vegetables Consumption vs FriedPotato Consumption with Heart Disease ", y=1.05)
plt.show();

# %% [markdown]
# From the above graph, we can see that the people with cardiovascular diseases are concentrated in the areas where the consumption of both green vegetables and fried potatoes is less than 40 times a month.

# %% [markdown]
# It is unclear if the consumption of fried potatoes and green vegetables influences people's cardiovascular health or if having cardiavascular disease influences the eating habits of people. Given the limited data, we aren't able to conclude if there is a correlation between food habits and cardiovascular health but we are able to derive that food habits don't differ when comparing people with and without cardiovascular diseases.

# %% [markdown]
# # 4. Conclusions and Future Work

# %% [markdown]
# Our data analysis has several important insights regarding the relationship between various health conditions, lifestyle factors, and the risk of cardiovascular disease (CVD).
#
# Firstly, we observed that depression significantly influences the probability of developing heart disease, particularly when coexisting with arthritis and diabetes hence we can focus on damage control by not letting these pre-existing health conditions affect our mental health.
#
# Secondly, exercise plays a crucial role in mitigating CVD risk, especially for individuals dealing with other cancer and arthritis.
# Notably, exercising is highly beneficial for those with a history of smoking, emphasizing its importance in preventing CVD.
#
# Additionally, a strong correlation exists between self-reported general health and cardiovascular disease risk, with age-related reporting due to the factor of ignorance as a youth compared to actually having experienced the damages it can cause to the human body.  Alternatively, it can also be due to the potential variations in immune system strength of the different age groups.
#
# Lastly, while the relationship between food habits and cardiovascular health remains inconclusive due to limited data, it's evident that dietary habits don't significantly differ between those with and without cardiovascular diseases. These findings underscore the importance of addressing mental health, adopting a regular exercise regimen, and improving overall health to effectively reduce the risk of cardiovascular disease.

# %% [markdown]
# # 5. References
#
# 1. Christina Antza, Antonio Gallo, Chrysoula Boutari, Alexandra Ershova, Kadri Murat Gurses, Joanna Lewek, Mirakhmadjon Mirmaksudov, Günther Silbernagel, Joakim Sandstedt, Anna Lebedeva,
# Prevention of cardiovascular disease in young adults: Focus on gender differences. A collaborative review from the EAS Young Fellows,
# Atherosclerosis,
# 2023,
# 117272,
# ISSN 0021-9150,
# https://doi.org/10.1016/j.atherosclerosis.2023.117272.
# (https://www.sciencedirect.com/science/article/pii/S0021915023051936)
